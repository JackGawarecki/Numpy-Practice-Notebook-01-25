# %% [markdown]
# # Practice Notebook: Numpy. After completeion submit it via moodle  (100 points)

# %% [markdown]
# ## 1. Import numpy, Image, PrettyTable, random libraries

# %%
import numpy as np
from PIL import Image
from prettytable import PrettyTable
import random

# %% [markdown]
# ## 2. Open any two images from the image list using Image library and save it to image1, and image2

# %%
Image1=Image.open('Pic1.jfif')
Image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=444x355 at 0x1C2A289A2B0>

# %%
Image2=Image.open('Pic2.jfif')
Image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=442x355 at 0x1C2A289A8B0>

# %% [markdown]
# ## 3. Color image is a 3d Numpy array. Find out the shape of each of those images and save it array1, and array2

# %%
array1=np.array(Image1)
array1
array1.shape
# Out:
# (355, 444, 3)

# %%
array2=np.array(Image2)
array2
array2.shape
# Out:
# (355, 442, 3)

# %% [markdown]
# ## 4. If two of the image is different size, resize them. You can either resize both of them in a particular size like 400x400 or resize either of them
#
# ### use resize library from PIL
# Sample: resizedimage=image1.resize((400,400), resample=Image.NEAREST)

# %%
resizedimage=Image1.resize((442,355))
resizedimage
# Out:
# <PIL.Image.Image image mode=RGB size=442x355 at 0x1C2A20AE550>

# %%
resizedimage2=Image2.resize((442,355))      # Shape gives height width, you put in width height
resizedimage2
# Out:
# <PIL.Image.Image image mode=RGB size=442x355 at 0x1C2A20AE220>

# %% [markdown]
# # Find the shape of each of the resized images and call them array1 and array2

# %%
array1=np.array(resizedimage)
array1.shape
# Out:
# (355, 442, 3)

# %%
array2=np.array(resizedimage2)
array2.shape
# Out:
# (355, 442, 3)

# %% [markdown]
# ## 5.  Write down a function called "inspect" to inspect array1 and array2 Shape, length, Dimensions, and Datatype using Preetytable. Your pretty table should contain a title and look like similar to the following:
# ![image-2.png](attachment:image-2.png)

# %%
def inspect(array):
    PT=PrettyTable()
    PT.title= 'Numpy array Inspection'
    PT.field_names=['Shape', 'Len', 'Dimensions','DataType']
    PT.add_row([array.shape, len(array), array.ndim, array.dtype])
    print(PT)
inspect(array1)
# Out:
# +---------------------------------------------+
# |            Numpy array Inspection           |
# +---------------+-----+------------+----------+
# |     Shape     | Len | Dimensions | DataType |
# +---------------+-----+------------+----------+
# | (355, 442, 3) | 355 |     3      |  uint8   |
# +---------------+-----+------------+----------+

# %%
inspect(array2)
# Out:
# +---------------------------------------------+
# |            Numpy array Inspection           |
# +---------------+-----+------------+----------+
# |     Shape     | Len | Dimensions | DataType |
# +---------------+-----+------------+----------+
# | (355, 442, 3) | 355 |     3      |  uint8   |
# +---------------+-----+------------+----------+

# %% [markdown]
# ## 6. Perform Element wise and Array Wise comparison of array1 and array2 and add necessary comments

# %%
array1==array2
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
array1<array2
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
array1>array2
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
np.array_equal(array1,array2)
# Out:
# False

# %% [markdown]
# ## 7. Create a 3D random array of size of your array1 and array2, give it name array3

# %%
array3=np.random.random((355,442,3))
array3
# Out:
# array([[[0.88384779, 0.46083033, 0.65911689],
#         [0.93298086, 0.64959839, 0.27740157],
#         [0.57002698, 0.64050276, 0.40807618],
#         ...,
#         [0.66138193, 0.53812113, 0.3068288 ],
#         [0.11091676, 0.89530145, 0.02192501],
#         [0.68827029, 0.28848913, 0.00825195]],
#
#        [[0.2954511 , 0.90583792, 0.67840182],
#         [0.88389832, 0.4562394 , 0.89422815],
#         [0.21129733, 0.45965283, 0.27029454],
#         ...,
#         [0.97379235, 0.31384672, 0.72067937],
#         [0.5916714 , 0.78245256, 0.80435236],
#         [0.84479675, 0.01374056, 0.68577201]],
#
#        [[0.6455947 , 0.66262858, 0.02505531],
#         [0.61400529, 0.07342244, 0.69091268],
#         [0.09511985, 0.88057688, 0.63097143],
#         ...,
#         [0.01694823, 0.3351606 , 0.39896399],
#         [0.89987775, 0.26419454, 0.71164065],
#         [0.24235004, 0.92586429, 0.73912478]],
#
#        ...,
#
#        [[0.88995646, 0.58246047, 0.78038146],
#         [0.96351131, 0.77804385, 0.7255967 ],
#         [0.17954278, 0.11518393, 0.43152856],
#         ...,
#         [0.72352379, 0.16244128, 0.61354714],
#         [0.09853124, 0.34947002, 0.4290733 ],
#         [0.41331295, 0.59875604, 0.71419317]],
#
#        [[0.89364922, 0.83537292, 0.28528368],
#         [0.08801849, 0.12991948, 0.72663627],
#         [0.88081165, 0.30739294, 0.68665047],
#         ...,
#         [0.01520859, 0.22455119, 0.58613003],
#         [0.26006666, 0.70263113, 0.09207344],
#         [0.7780631 , 0.02192897, 0.1526033 ]],
#
#        [[0.57726805, 0.92842536, 0.47308435],
#         [0.88527198, 0.60273293, 0.26746926],
#         [0.94245115, 0.18214402, 0.7586942 ],
#         ...,
#         [0.73118002, 0.02369395, 0.63502067],
#         [0.94162116, 0.49344334, 0.57780792],
#         [0.18391082, 0.7508269 , 0.91892367]]])

# %% [markdown]
# ## 8.Create a function called "calculation" to display `sum, min, max, mean, standard deviation, median calculations about a NumPy array using PrettyTable. Test it for array1,2,3
# ![image.png](attachment:image.png)

# %%
def calculation(array):
    PT=PrettyTable()
    PT.title='Numpy array Calculations'
    PT.field_names=['Sum','Min','Max','Mean','Std','Median']
    PT.add_row([array.sum(), array.min(), array.max(), array.mean(), np.std(array), np.median(array)])
    print(PT)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy array Calculations                       |
# +----------+-----+-----+-------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mean       |        Std        | Median |
# +----------+-----+-----+-------------------+-------------------+--------+
# | 35556826 |  0  | 255 | 75.53550018057061 | 70.78033277647297 |  60.0  |
# +----------+-----+-----+-------------------+-------------------+--------+

# %%
calculation(array1)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy array Calculations                       |
# +----------+-----+-----+-------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mean       |        Std        | Median |
# +----------+-----+-----+-------------------+-------------------+--------+
# | 35556826 |  0  | 255 | 75.53550018057061 | 70.78033277647297 |  60.0  |
# +----------+-----+-----+-------------------+-------------------+--------+

# %%
calculation(array2)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy array Calculations                       |
# +----------+-----+-----+-------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mean       |        Std        | Median |
# +----------+-----+-----+-------------------+-------------------+--------+
# | 39434318 |  0  | 255 | 83.77268922737025 | 69.98954058886022 |  61.0  |
# +----------+-----+-----+-------------------+-------------------+--------+

# %%
calculation(array3)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------+
# |                                                   Numpy array Calculations                                                  |
# +-------------------+-----------------------+--------------------+-------------------+--------------------+-------------------+
# |        Sum        |          Min          |        Max         |        Mean       |        Std         |       Median      |
# +-------------------+-----------------------+--------------------+-------------------+--------------------+-------------------+
# | 235471.7644842263 | 9.042885736887385e-07 | 0.9999995456003445 | 0.500226806203612 | 0.2884674355980255 | 0.500196779311193 |
# +-------------------+-----------------------+--------------------+-------------------+--------------------+-------------------+

# %% [markdown]
# ## 9.Create a function called "arithmatic" to display `Subtraction (np.subtract(a,b)), Addition,  Multiplication calculations about two NumPy array using PrettyTable. Test it for
# * array1, array3
# * array2, array3
# * array1, array2
# ![image.png](attachment:image.png)

# %%
def arithmatic(a,b):
    PT=PrettyTable()
    PT.title='Numpy Arithmatic Calculations'
    PT.field_names=['Subtraction','Addition','Multiplication']
    PT.add_row([np.subtract(a,b), np.add(a,b),np.multiply(a,b)])
    print(PT)

# %%
arithmatic(array1,array2)
# Out:
# +-----------------------------------------------------------+
# |               Numpy Arithmatic Calculations               |
# +-------------------+-------------------+-------------------+
# |    Subtraction    |      Addition     |   Multiplication  |
# +-------------------+-------------------+-------------------+
# |  [[[ 50  59  57]  |  [[[ 50  85 133]  |  [[[  0 168  26]  |
# |    [ 57  65  63]  |    [ 57  93 141]  |    [  0  82 138]  |
# |    [ 37  44  42]  |    [ 37  74 122]  |    [  0 117 208]  |
# |         ...       |         ...       |         ...       |
# |    [243 224 202]  |    [ 19  36  54]  |    [ 48  68   0]  |
# |    [241 222 198]  |    [ 21  38  58]  |    [ 54  72   0]  |
# |    [241 222 196]] |    [ 21  38  60]] |    [ 54  72   0]] |
# |                   |                   |                   |
# |   [[ 43  53  50]  |   [[ 43  83 130]  |   [[  0 252  16]  |
# |    [ 46  56  53]  |    [ 46  86 133]  |    [  0  41 136]  |
# |    [ 39  48  45]  |    [ 39  80 127]  |    [  0   0 198]  |
# |         ...       |         ...       |         ...       |
# |    [241 223 201]  |    [ 17  35  57]  |    [ 16  34  56]  |
# |    [239 221 199]  |    [ 19  37  59]  |    [ 18  36  58]  |
# |    [239 221 197]] |    [ 19  37  61]] |    [ 18  36  60]] |
# |                   |                   |                   |
# |   [[ 40  49  46]  |   [[ 42  83 130]  |   [[ 41  98 112]  |
# |    [ 32  41  38]  |    [ 34  75 122]  |    [ 33 218  32]  |
# |    [ 39  48  45]  |    [ 41  82 129]  |    [ 40  81  70]  |
# |         ...       |         ...       |         ...       |
# |    [240 222 200]  |    [ 16  34  56]  |    [  0   0   0]  |
# |    [238 220 198]  |    [ 18  36  58]  |    [  0   0   0]  |
# |    [238 220 196]] |    [ 18  36  60]] |    [  0   0   0]] |
# |                   |                   |                   |
# |         ...       |         ...       |         ...       |
# |                   |                   |                   |
# |   [[212 160 113]  |   [[ 44  96 143]  |   [[  0   0   0]  |
# |    [209 157 110]  |    [ 47  99 146]  |    [  0   0   0]  |
# |    [207 155 108]  |    [ 49 101 148]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [132  80  43]  |    [124 176 213]  |    [  0   0   0]  |
# |    [123  71  32]  |    [133 185 224]  |    [  0   0   0]  |
# |    [138  84  46]] |    [140 194 232]] |    [139 221 127]] |
# |                   |                   |                   |
# |   [[211 159 112]  |   [[ 45  97 144]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [209 157 110]  |    [ 47  99 146]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [130  78  41]  |    [128 180 217]  |    [127 179 216]  |
# |    [135  83  44]  |    [135 187 226]  |    [128 236 253]  |
# |    [180 126  88]] |    [172 226   8]] |    [ 64  96 128]] |
# |                   |                   |                   |
# |   [[209 157 110]  |   [[ 47  99 146]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [211 159 112]  |    [ 45  97 144]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [127  75  38]  |    [129 181 218]  |    [  0   0   0]  |
# |    [136  84  45]  |    [132 184 223]  |    [244  44  22]  |
# |   [197 143 105]]] |   [183 237  19]]] |   [ 78  98 150]]] |
# +-------------------+-------------------+-------------------+

# %%
arithmatic(array1,array3)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                  Numpy Arithmatic Calculations                                                                  |
# +-------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |                      Subtraction                      |                      Addition                      |                   Multiplication                   |
# +-------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  [[[ 4.91161522e+01  7.15391697e+01  9.43408831e+01]  |  [[[5.08838478e+01 7.24608303e+01 9.56591169e+01]  |  [[[4.41923895e+01 3.31797834e+01 6.26161048e+01]  |
# |    [ 5.60670191e+01  7.83504016e+01  1.01722598e+02]  |    [5.79329809e+01 7.96495984e+01 1.02277402e+02]  |    [5.31799092e+01 5.13182726e+01 2.82949599e+01]  |
# |    [ 3.64299730e+01  5.83594972e+01  8.15919238e+01]  |    [3.75700270e+01 5.96405028e+01 8.24080762e+01]  |    [2.10909981e+01 3.77896631e+01 3.34622469e+01]  |
# |                           ...                         |                         ...                        |                         ...                        |
# |    [ 2.33861807e+00  1.46187887e+00 -3.06828797e-01]  |    [3.66138193e+00 2.53812113e+00 3.06828797e-01]  |    [1.98414580e+00 1.07624226e+00 0.00000000e+00]  |
# |    [ 2.88908324e+00  1.10469855e+00 -2.19250109e-02]  |    [3.11091676e+00 2.89530145e+00 2.19250109e-02]  |    [3.32750283e-01 1.79060291e+00 0.00000000e+00]  |
# |    [ 2.31172971e+00  1.71151087e+00 -8.25194902e-03]] |   [3.68827029e+00 2.28848913e+00 8.25194902e-03]]  |   [2.06481086e+00 5.76978268e-01 0.00000000e+00]]  |
# |                                                       |                                                    |                                                    |
# |   [[ 4.27045489e+01  6.70941621e+01  8.93215982e+01]  |   [[4.32954511e+01 6.89058379e+01 9.06784018e+01]  |   [[1.27043973e+01 6.15969787e+01 6.10561642e+01]  |
# |    [ 4.51161017e+01  7.05437606e+01  9.21057719e+01]  |    [4.68838983e+01 7.14562394e+01 9.38942281e+01]  |    [4.06593227e+01 3.23929972e+01 8.31632178e+01]  |
# |    [ 1.23221937e+02  1.77978071e+02  2.15847397e+02]] |   [1.24778063e+02 1.78021929e+02 2.16152603e+02]]  |   [9.64798239e+01 3.90335706e+00 3.29623132e+01]]  |
# |                                                       |                                                    |                                                    |
# |   [[ 4.64227319e+01  9.80715746e+01  1.45526916e+02]  |   [[4.75772681e+01 9.99284254e+01 1.46473084e+02]  |   [[2.71315986e+01 9.19141103e+01 6.90703154e+01]  |
# |    [ 4.51147280e+01  9.73972671e+01  1.44732531e+02]  |    [4.68852720e+01 9.86027329e+01 1.45267469e+02]  |    [4.07225112e+01 5.90678276e+01 3.87830428e+01]  |
# |    [ 4.40575488e+01  9.68178560e+01  1.43241306e+02]  |    [4.59424512e+01 9.71821440e+01 1.44758694e+02]  |    [4.24103019e+01 1.76679698e+01 1.09251965e+02]  |
# |                           ...                         |                         ...                        |                         ...                        |
# |    [ 1.28268820e+02  1.80976306e+02  2.17364979e+02]  |    [1.29731180e+02 1.81023694e+02 2.18635021e+02]  |    [9.43222220e+01 4.28860491e+00 1.38434505e+02]  |
# |    [ 1.25058379e+02  1.77506557e+02  2.16422192e+02]  |    [1.26941621e+02 1.78493443e+02 2.17577808e+02]  |    [1.18644266e+02 8.78329141e+01 1.25384318e+02]  |
# |   [ 1.20816089e+02  1.74249173e+02  2.12081076e+02]]] |   [1.21183911e+02 1.75750827e+02 2.13918924e+02]]] |   [2.22532095e+01 1.31394708e+02 1.95730741e+02]]] |
# +-------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %% [markdown]
# ## 10. What is the difference between reshape and resize? Reshape and resize 3D array2 to a 2D array. Make sure keep in mind the original shape.

# %% [markdown]
# #### Reshape does not change the original array, but only returns the chagned one

# %%
array2.reshape(235365,2)
# Out:
# array([[  0,  13],
#        [ 38,   0],
#        [ 14,  39],
#        ...,
#        [126, 178],
#        [217, 121],
#        [175, 213]], dtype=uint8)

# %% [markdown]
# ## 11. Vertically stack array1 and array3 and create new array4

# %%
array4=np.vstack((array1,array3))
array4
# Out:
# array([[[5.00000000e+01, 7.20000000e+01, 9.50000000e+01],
#         [5.70000000e+01, 7.90000000e+01, 1.02000000e+02],
#         [3.70000000e+01, 5.90000000e+01, 8.20000000e+01],
#         ...,
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00]],
#
#        [[4.30000000e+01, 6.80000000e+01, 9.00000000e+01],
#         [4.60000000e+01, 7.10000000e+01, 9.30000000e+01],
#         [3.90000000e+01, 6.40000000e+01, 8.60000000e+01],
#         ...,
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00]],
#
#        [[4.10000000e+01, 6.60000000e+01, 8.80000000e+01],
#         [3.30000000e+01, 5.80000000e+01, 8.00000000e+01],
#         [4.00000000e+01, 6.50000000e+01, 8.70000000e+01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[8.89956464e-01, 5.82460470e-01, 7.80381463e-01],
#         [9.63511305e-01, 7.78043848e-01, 7.25596699e-01],
#         [1.79542775e-01, 1.15183930e-01, 4.31528557e-01],
#         ...,
#         [7.23523787e-01, 1.62441282e-01, 6.13547137e-01],
#         [9.85312401e-02, 3.49470018e-01, 4.29073300e-01],
#         [4.13312950e-01, 5.98756043e-01, 7.14193165e-01]],
#
#        [[8.93649225e-01, 8.35372917e-01, 2.85283679e-01],
#         [8.80184887e-02, 1.29919478e-01, 7.26636270e-01],
#         [8.80811655e-01, 3.07392937e-01, 6.86650468e-01],
#         ...,
#         [1.52085895e-02, 2.24551193e-01, 5.86130026e-01],
#         [2.60066662e-01, 7.02631131e-01, 9.20734396e-02],
#         [7.78063096e-01, 2.19289722e-02, 1.52603302e-01]],
#
#        [[5.77268055e-01, 9.28425356e-01, 4.73084352e-01],
#         [8.85271983e-01, 6.02732935e-01, 2.67469260e-01],
#         [9.42451154e-01, 1.82144018e-01, 7.58694205e-01],
#         ...,
#         [7.31180015e-01, 2.36939498e-02, 6.35020666e-01],
#         [9.41621157e-01, 4.93443337e-01, 5.77807918e-01],
#         [1.83910823e-01, 7.50826905e-01, 9.18923668e-01]]])

# %% [markdown]
# ## 12. Save array4 at your system and load it back

# %%
np.save('Array4.npy',array4)

# %%
np.load('Array4.npy')
# Out:
# array([[[5.00000000e+01, 7.20000000e+01, 9.50000000e+01],
#         [5.70000000e+01, 7.90000000e+01, 1.02000000e+02],
#         [3.70000000e+01, 5.90000000e+01, 8.20000000e+01],
#         ...,
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00]],
#
#        [[4.30000000e+01, 6.80000000e+01, 9.00000000e+01],
#         [4.60000000e+01, 7.10000000e+01, 9.30000000e+01],
#         [3.90000000e+01, 6.40000000e+01, 8.60000000e+01],
#         ...,
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00]],
#
#        [[4.10000000e+01, 6.60000000e+01, 8.80000000e+01],
#         [3.30000000e+01, 5.80000000e+01, 8.00000000e+01],
#         [4.00000000e+01, 6.50000000e+01, 8.70000000e+01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[8.89956464e-01, 5.82460470e-01, 7.80381463e-01],
#         [9.63511305e-01, 7.78043848e-01, 7.25596699e-01],
#         [1.79542775e-01, 1.15183930e-01, 4.31528557e-01],
#         ...,
#         [7.23523787e-01, 1.62441282e-01, 6.13547137e-01],
#         [9.85312401e-02, 3.49470018e-01, 4.29073300e-01],
#         [4.13312950e-01, 5.98756043e-01, 7.14193165e-01]],
#
#        [[8.93649225e-01, 8.35372917e-01, 2.85283679e-01],
#         [8.80184887e-02, 1.29919478e-01, 7.26636270e-01],
#         [8.80811655e-01, 3.07392937e-01, 6.86650468e-01],
#         ...,
#         [1.52085895e-02, 2.24551193e-01, 5.86130026e-01],
#         [2.60066662e-01, 7.02631131e-01, 9.20734396e-02],
#         [7.78063096e-01, 2.19289722e-02, 1.52603302e-01]],
#
#        [[5.77268055e-01, 9.28425356e-01, 4.73084352e-01],
#         [8.85271983e-01, 6.02732935e-01, 2.67469260e-01],
#         [9.42451154e-01, 1.82144018e-01, 7.58694205e-01],
#         ...,
#         [7.31180015e-01, 2.36939498e-02, 6.35020666e-01],
#         [9.41621157e-01, 4.93443337e-01, 5.77807918e-01],
#         [1.83910823e-01, 7.50826905e-01, 9.18923668e-01]]])
